# %%
print("Hello world")
# Out:
# Hello world

# %%
name = "k"
name     = "kashaf"
age      = 21
gpa      = 3.6
is_smart = True
nothing  = None

# %%
print(name)
print(age)
print(gpa)
print(is_smart)
print(nothing)
# Out:
# kashaf
# 21
# 3.6
# True
# None

# %%
# Check the type of anything
print(type(name))   # <class 'str'>
print(type(age))    # <class 'int'>
print(type(gpa))    # <class 'float'>
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>

# %%
x = int("20")         # str → int: 20
y = float(6)          # int → float: 6.0
z = str(100)           # int → str: "100"
b = bool(0)           # int → bool: False
b2 = bool("hi")      # str → bool: True

# %%
print(type(x))  # <class 'int'>
print(type(y))  # <class 'float'>
print(type(z))  # <class 'str'>
print(type(b))  # <class 'bool'>
print(type(b2)) # <class 'bool'>
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>
# <class 'bool'>

# %%
s = "Hello, World!"
print(len(s))          # 13
print(s[0])            # H  (indexing)
print(s[-1])           # !  (last char)
print(s[0:5])          # Hello (slicing)

# %%
s = "Hello, World!"
print(len(s))          # 13
print(s[0])            # H  (indexing)
print(s[-1])           # !  (last char)
print(s[0:5])          # Hello (slicing)
# Out:
# 13
# H
# !
# Hello

# %%
print(s[7:])          # Hello (slicing)
# Out:
# World!

# %%
name = "kashaf"
age  = 21


msg  = f"My name is {name} and I am {age} years old."
msg2 = "My name is {} and I am {} years old.".format(name, age)

print(msg)
print(msg2)
# Out:
# My name is kashaf and I am 21 years old.
# My name is kashaf and I am 21 years old.

# %%
msg3 = "my name is " + name + " and I am " + str(age) + " years old."
msg3
# Out:
# 'my name is kashaf and I am 21 years old.'

# %%
s = "  python is awesome     "

a = s.strip()           # "python is awesome"

# %%
s.upper()           # "  PYTHON IS AWESOME  "
# Out:
# '  PYTHON IS AWESOME     '

# %%
s.lower()           # "  python is awesome  "
# Out:
# '  python is awesome     '

# %%
s.replace("awesome", "great")   # replace word
# Out:
# '  python is great     '

# %%
a
# Out:
# 'python is awesome'

# %%
s.split()           # ['python', 'is', 'awesome']
# Out:
# ['python', 'is', 'awesome']

# %%
# string start with spicific letter or not
s.startswith("  py")# True
# Out:
# True

# %%
# count quantity of words/charcter
s.count("s")       # 2
# Out:
# 2

# %%
# combine mulyiple string in one string
"-".join(["a","b","c"]) # "a-b-c"
# Out:
# 'a-b-c'

# %%
a, b = 10, 3
a =10
b=3

print(a + b)    # 13  (addition)
print(a - b)    # 7   (subtraction)
print(a * b)    # 30  (multiplication)
print(a / b)    # 3.333  (division → float)
print(a // b)   # 3   (floor division)
print(a % b)    # 1   (modulo / remainder)
print(a ** b)   # 1000 (power: 10³)
# Out:
# 13
# 7
# 30
# 3.3333333333333335
# 3
# 1
# 1000

# %%
x=5

print(x == 5)   # True  (equal)
print(x != 3)   # True  (not equal)
print(x >  3)   # True  (greater)
print(x <  10)  # True  (less)
print(x >= 5)   # True  (greater or equal)
print(x <= 4)   # False (less or equal)
# Out:
# True
# True
# True
# True
# True
# False

# %%
a = True
b = False

print(a and b)   # False (both must be True)
print(a or  b)   # True  (at least one True)
print(not a)     # False (flips the value)

# Combined
x = 7
print(x > 5 and x < 10)  # True
# Out:
# False
# True
# False
# True

# %%
for i in range(5):
    print(i)     # 0 1 2 3 4
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
for i in range(2, 10, 2):
    print(i)     # 2 4 6 8  (start, stop, step)
# Out:
# 2
# 4
# 6
# 8

# %%
langs = ["Python", "JS", "Rust","golang"]
for lang in langs:
    print(lang)
# Out:
# Python
# JS
# Rust
# golang

# %%
count = 0  
while count < 5:
    print(count)
    count += 1
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
for i in range(10):
    if i == 5:
        break
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
for i in range(5):
    if i == 2: continue
    print(i)
# Out:
# 0
# 1
# 3
# 4

# %%
# enumerate — index + value together
for idx, val in enumerate(["a","b","c"]):
    print(idx, val) # 0 a / 1 b / 2 c
# Out:
# 0 a
# 1 b
# 2 c
